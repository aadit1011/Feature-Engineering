# %%
import pandas as pd 
import numpy as np 
import seaborn as sns 
import matplotlib.pyplot as plt 
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score,r2_score
from sklearn.compose import ColumnTransformer
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import LogisticRegression

# %%
df=pd.read_csv('World Largest Cities by Population 2024.csv')
df.drop(columns=['Unnamed: 0'])
# Out:
#                City         Country  Population (2024)  Population (2023)  \
# 0             Tokyo           Japan           37115035           37194105
# 1             Delhi           India           33807403           32941309
# 2          Shanghai           China           29867918           29210808
# 3             Dhaka      Bangladesh           23935652           23209616
# 4         Sao Paulo          Brazil           22806704           22619736
# ..              ...             ...                ...                ...
# 796       Bhavnagar           India             751493             737128
# 797       Sheffield  United Kingdom             751303             745876
# 798          Huambo          Angola             751297             727641
# 799  Ribeirao Preto          Brazil             750174             742115
# 800       Panzhihua           China             750036             738495
#
#      Growth Rate
# 0        -0.0021
# 1         0.0263
# 2         0.0225
# ...

# %%
from scipy.stats import probplot
plt.figure(figsize=(14,4))
plt.subplot(121)
probplot(df['Population (2023)'],plot=plt)
plt.savefig('City Population In 2023.png')

plt.subplot(122)
probplot(df['Population (2024)'],plot=plt)
plt.savefig('City Population In 2024.png')
plt.show()

# %%
df['Population (2023)'].mean()
# Out:
# 2604461.22721598

# %%
df['Population (2024)'].mean()
# Out:
# 2654327.329588015

# %%
df['Population (2023)'].median()
# Out:
# 1363510.0

# %%
df['Population (2024)'].median()
# Out:
# 1379368.0

# %%
plt.figure(figsize=(14,4))
plt.subplot(121)
sns.kdeplot(df['Population (2023)'])

plt.subplot(122)
sns.kdeplot(df['Population (2024)'])
plt.show()
